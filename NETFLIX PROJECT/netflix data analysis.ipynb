# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Netflix Data.csv")
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#PRINT TOP 5
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
#PRINT LAST 5
data.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country Release_Date Rating  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# ...

# %%
#DATABASE SHAPE
data.shape
# Out:
# (7789, 11)

# %%
#DATA SIZE
data.size
# Out:
# 85679

# %%
#SHOW NAME OF EACH COLUMN
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#SHOW TYPES OF COLUMN
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#SHOW INDEX,COLUMNS,DATATYPES OF EACH COLUMNS
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
# SHOWING DUPLICATE DATAS
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6300     5-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622     4-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#DELETING DUPLICATES
data.drop_duplicates(inplace=True)

# %%
#SHOWING NULL VALUES COUNT
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#SHOWING IS THEIR ANY NULL VALUES
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
#GRAPHICALLY OF MOVIES AND TV SHOWS
sns.countplot(x="Category",data=data)  #BY SEABORN
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
# BY MATPLOTLIB
category=np.array(["MOVIES","TV SHOW"])
numbers=np.array([5377,2410])
plt.pie(numbers,labels=category)
plt.show()

# %%
#HIGHEST RATING IN TV-MA(mature audience)
data_rating=data[data['Rating']=='TV-MA']
data_rating.Duration.value_counts()
# Out:
# 1 Season     690
# 2 Seasons    163
# 3 Seasons     84
# 90 min        51
# 94 min        48
#             ...
# 161 min        1
# 154 min        1
# 171 min        1
# 182 min        1
# 157 min        1
# Name: Duration, Length: 155, dtype: int64

# %%
#REMOVE NA VALUES
ndata=data.dropna()

# %%
#TOP 10 COUNTRY
data.groupby("Country").Country.max()
data.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
#TOP 10 COUNTRY GRAPHICALLY REPRESENTATION
country=np.array(["France","Brazil","Argentina","Poland","Germany","Denmark","Chile","Peru"])
counting=np.array([115,72,50,20,61,13,14,4])
plt.bar(country,counting,width=0.5)
plt.show()

# %%
#YEAR BY RATING
year=np.array([2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])
rating=np.array([2,2,1,15,3,12,8,16,159,369,463,731,678,55])
f1={'family':"monospace",'color':'red','size':20}
plt.xlabel("YEAR",fontdict=f1)
plt.ylabel("RATING",fontdict=f1)
plt.bar(year,rating,width=0.5)
plt.show()

# %%
#TOP 10 DIRECTORS WHOSE DURATION IS HIGH
data.sort_values('Director',ascending=False,inplace=True)
data.head(10)
# Out:
#      Show_Id Category                  Title  \
# 2661   s2662    Movie          Hayat Öpücügü
# 3380   s3381    Movie    Kill Me If You Dare
# 263     s264    Movie  Aşk Tesadüfleri Sever
# 2324   s2325    Movie                G.O.R.A
# 41       s42    Movie             Ég man þig
# 505     s506    Movie   And Breathe Normally
# 664     s665    Movie         Babam ve Oğlum
# 1821   s1822    Movie           Don’t Listen
# 7287   s7286    Movie         Two Catalonias
# 5175   s5175    Movie                Retablo
#
#                                Director  \
# 2661                       Şenol Sönmez
# 3380                       Şenol Sönmez
# 263                    Ömer Faruk Sorak
# 2324                   Ömer Faruk Sorak
# 41                  Óskar Thór Axelsson
# 505                    Ísold Uggadóttir
# 664                         Çagan Irmak
# 1821              Ángel Gómez Hernández
# 7287  Álvaro Longoria, Gerardo Olivares
# 5175         Álvaro Delgado-Aparicio L.
#
# ...

# %%
#top 10 directors  
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
#top 5 directors on netflix
directors=np.array(["Raúl Campos","Jan Suter","Marcus Raboy","Jay Karas","Cathy Garcia-Molina "])
number=np.array([9,9,16,14,13])
plt.pie(number,labels=directors)
plt.show()

# %%
#TOP 20 CATEGORY WHOSE RATING IS HIGHEST
data.sort_values('Rating',ascending=False,inplace=True)
data.head(20)
# Out:
#      Show_Id Category                                              Title  \
# 7730   s7729    Movie                      You Don't Mess with the Zohan
# 5523   s5523    Movie                                           Sex Doll
# 5574   s5574    Movie                            Shootout at Lokhandwala
# 2953   s2954    Movie                                      Immoral Tales
# 2484   s2485    Movie                                    Good Luck Chuck
# 4589   s4590  TV Show                      Oh No! It's an Alien Invasion
# 4241   s4242    Movie                          Motu Patlu: King of Kings
# 3668   s3669    Movie                Little Singham aur Kaal ka Mahajaal
# 3593   s3594    Movie  LEGO Ninjago: Masters of Spinjitzu: Day of the...
# 1662   s1663    Movie                                       Dear Dracula
# 3601   s3602    Movie                                       Leo the Lion
# 1769   s1770  TV Show                                      Dinosaur King
# ...

# %%
#for house of cards what is show id and who is the director of this show
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#how many tv and movies are their in dataset
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#SEPRATE RELASES DATE
data['Date']=pd.to_datetime(data['Release_Date'])

# %%
#SEPRATE YEAR BY DATE
data['Year']=data['Date'].dt.year

# %%
#occurance of individual year
data['Date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
#graph for cheking the individual occurance 
d=np.array([2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])
counts=np.array([2,1,13,3,11,25,88,443,1225,1685,2153,2009,117])
plt.plot(d,counts)
plt.show()

# %%
#checking which category was release in 2013
#syntax for filtering:  data[data(column name)=='sepicify data'&(data['column name']=='specify data')]
data[(data['Category']=='Movie')&(data['Year']==2013)]
# Out:
#      Show_Id Category                        Title  \
# 649     s650    Movie    Aziz Ansari: Buried Alive
# 5588   s5588    Movie            Shrek the Musical
# 6866   s6865    Movie               The Short Game
# 2948   s2949    Movie  Iliza Shlesinger: War Paint
# 5315   s5315    Movie    Russell Peters: Notorious
# 220     s221    Movie   A Russell Peters Christmas
#
#                            Director  \
# 649   Will Lovelace, Dylan Southern
# 5588                    Jason Moore
# 6866                 Josh Greenbaum
# 2948                    Jay Chapman
# 5315                     Dave Higby
# 220              Henry Sarwer-Foner
#
#                                                    Cast        Country  \
# 649                                         Aziz Ansari  United States
# 5588  Brian d'Arcy James, Daniel Breaker, Sutton Fos...  United States
# 6866  Sky Sudberry, Allan Kournikova, Jed Dy, Zamoku...  United States
# ...

# %%
#show specific tv shows details of united states
data[(data['Category']=='TV Show')&(data['Country']=='United States')]
# Out:
#      Show_Id Category                                  Title Director  \
# 1856   s1857  TV Show              Dragons: Race to the Edge      NaN
# 5845   s5845  TV Show  Stretch Armstrong & the Flex Fighters      NaN
# 1770   s1771  TV Show                               Dinotrux      NaN
# 5761   s5761  TV Show                    Spirit: Riding Free      NaN
# 1646   s1647  TV Show                    DC Super Hero Girls      NaN
# ...      ...      ...                                    ...      ...
# 504     s505  TV Show                         Ancient Aliens      NaN
# 306     s307  TV Show                  Adam Ruins Everything      NaN
# 288     s289  TV Show            Abstract: The Art of Design      NaN
# 5138   s5138  TV Show                           Red vs. Blue      NaN
# 5313   s5313  TV Show           Russell Peters vs. the World      NaN
#
#                                                    Cast        Country  \
# ...

# %%
#to show only titles of TV Show in united states
data[(data['Category']=='TV Show')&(data['Country']=='United States')]['Title']
# Out:
# 1856                Dragons: Race to the Edge
# 5845    Stretch Armstrong & the Flex Fighters
# 1770                                 Dinotrux
# 5761                      Spirit: Riding Free
# 1646                      DC Super Hero Girls
#                         ...
# 504                            Ancient Aliens
# 306                     Adam Ruins Everything
# 288               Abstract: The Art of Design
# 5138                             Red vs. Blue
# 5313             Russell Peters vs. the World
# Name: Title, Length: 705, dtype: object

# %%
#results where cateogory= movie and comedy or country=india
data[(data['Category']=='Movie')&(data['Type']=='Comedies') |(data['Country']=='India')]
# Out:
#      Show_Id Category                        Title  \
# 5574   s5574    Movie      Shootout at Lokhandwala
# 4241   s4242    Movie    Motu Patlu: King of Kings
# 244     s245    Movie            A truthful Mother
# 1322   s1323    Movie  Chhota Bheem Kungfu Dhamaka
# 5889   s5889    Movie   Super Bheem Bana Vajraveer
# ...      ...      ...                          ...
# 7163   s7162    Movie             Total Frat Movie
# 4633   s4634    Movie  Once Upon a Time in Mumbaai
# 2111   s2112    Movie                       Fandry
# 2817   s2818    Movie                      Hot Bot
# 7300   s7299    Movie                         Ugly
#
#                         Director  \
# 5574              Apoorva Lakhia
# 4241                 Suhas Kadav
# 244    Ravishankar Venkateswaran
# 1322  Rajiv Chilaka, Binayak Das
# 5889                   Sumit Das
# ...                          ...
# 7163            Warren P. Sonoda
# 4633               Milan Luthria
# 2111              Nagraj Manjule
# ...

# %%
#specific director 
data[data['Cast']=='João Miguel']
#this  will show no result because their is not any movie aor show which is only cast by João Miguel
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
ndata[ndata['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5071     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %%
#unique values in rating 
data['Rating'].unique()
# Out:
# array(['UR', 'TV-Y7-FV', 'TV-Y7', 'TV-Y', 'TV-PG', 'TV-MA', 'TV-G',
#        'TV-14', 'R', 'PG-13', 'PG', 'NR', 'NC-17', 'G', nan], dtype=object)

# %%
#know the tv shows rating 'TV-Y7' in canada
data[(data['Category']=='Movie')&(data['Rating']=='TV-14')&(data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 5393   s5393    Movie                                   Sardaar ji
# 7041   s7040    Movie               There's Something in the Water
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 608     s609    Movie                               At First Light
# 7025   s7024    Movie                         The Wrong Babysitter
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 5336   s5336    Movie                   Sadie's Last Days on Earth
#
#                                     Director  \
# 5393                            Rohit Jugraj
# 7041                  Ellen Page, Ian Daniel
# ...

# %%
#CHECKING THAT DATA OF MOVIES IN RATING OF TV-14 IN CANADA
data[(data['Category']=='Movie')&(data['Rating']=='TV-14')&(data['Country']=='Canada')].shape
# Out:
# (11, 13)

# %%
#CHECKING IF THEIR IS ANY DATA IN TV SHOW UNDER 2018 WITH RATING TV-14
data[(data['Category']=='Tv Show') & (data['Rating']=='TV-14')&(data['Year']>2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
#maximum duration 
data.Duration.unique()
# Out:
# array(['113 min', '103 min', '116 min', '99 min', '2 Seasons', '109 min',
#        '68 min', '44 min', '43 min', '78 min', '6 Seasons', '1 Season',
#        '3 Seasons', '5 Seasons', '67 min', '66 min', '69 min', '70 min',
#        '8 Seasons', '47 min', '98 min', '86 min', '4 Seasons', '55 min',
#        '14 min', '46 min', '76 min', '73 min', '115 min', '85 min',
#        '22 min', '92 min', '112 min', '63 min', '97 min', '87 min',
#        '79 min', '81 min', '24 min', '82 min', '104 min', '26 min',
#        '106 min', '93 min', '60 min', '61 min', '65 min', '23 min',
#        '96 min', '58 min', '25 min', '72 min', '10 Seasons', '77 min',
#        '48 min', '45 min', '88 min', '29 min', '62 min', '91 min',
#        '89 min', '27 min', '71 min', '127 min', '74 min', '75 min',
#        '30 min', '21 min', '42 min', '83 min', '90 min', '64 min',
#        '40 min', '3 min', '32 min', '80 min', '28 min', '35 min',
#        '37 min', '33 min', '11 min', '19 min', '59 min', '51 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
#SPLITING DURATION COLUMN
data[['Time','Unit']]=data['Duration'].str.split(' ',expand=True)
data
# Out:
#      Show_Id Category                                              Title  \
# 7730   s7729    Movie                      You Don't Mess with the Zohan
# 5523   s5523    Movie                                           Sex Doll
# 5574   s5574    Movie                            Shootout at Lokhandwala
# 2953   s2954    Movie                                      Immoral Tales
# 2484   s2485    Movie                                    Good Luck Chuck
# ...      ...      ...                                                ...
# 3736   s3737    Movie                                    Louis C.K. 2017
# 4323   s4324    Movie                               My Honor Was Loyalty
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 2359   s2360  TV Show                  Gargantia on the Verdurous Planet
# 3660   s3661  TV Show                                       Little Lunch
#
#                 Director                                               Cast  \
# ...

# %%
data['Time'].max()
# Out:
# '99'

# %%
data['Time'].min()
# Out:
# '1'

# %%
data['Time'].mean()
# Out:
# inf

# %%
#INDIVIDUAL COUNTRY HAVE HIGHEST TV SHOWS
data_tvshows=data[data['Category']=='TV Show']
data_tvshows.Country.value_counts()
# Out:
# United States                                 705
# United Kingdom                                204
# Japan                                         157
# South Korea                                   147
# India                                          71
#                                              ...
# United States, Sweden                           1
# United States, Italy                            1
# Denmark, Singapore, Canada, United States       1
# Australia, New Zealand                          1
# United States, Israel, Italy, South Africa      1
# Name: Country, Length: 183, dtype: int64

# %%
#SORT DATA BY YEAR
data.sort_values(by='Year')
# Out:
#      Show_Id Category                                        Title  \
# 7115   s7114    Movie                         To and From New York
# 1765   s1766  TV Show                              Dinner for Five
# 5766   s5766    Movie                                     Splatter
# 3248   s3249    Movie                      Just Another Love Story
# 3840   s3841    Movie                  Mad Ron's Prevues from Hell
# ...      ...      ...                                          ...
# 258     s259  TV Show  A Young Doctor's Notebook and Other Stories
# 3492   s3493  TV Show                          La Familia P. Luche
# 2555   s2556  TV Show                              Gunslinger Girl
# 2288   s2289  TV Show                                      Friends
# 5138   s5138  TV Show                                 Red vs. Blue
#
#                   Director                                               Cast  \
# 7115  Sorin Dan Mihalcescu  Barbara King, Shaana Diya, John Krisiukenas, Y...
# ...

# %%
data.sort_values(by='Year', ascending=False)
# Out:
#      Show_Id Category                                        Title  \
# 5060   s5060    Movie                                 Radium Girls
# 3062   s3063    Movie                          Is Love Enough? Sir
# 4710   s4711    Movie                             Outside the Wire
# 3483   s3484  TV Show                                L.A.’s Finest
# 4882   s4882    Movie                            Playing for Keeps
# ...      ...      ...                                          ...
# 258     s259  TV Show  A Young Doctor's Notebook and Other Stories
# 3492   s3493  TV Show                          La Familia P. Luche
# 2555   s2556  TV Show                              Gunslinger Girl
# 2288   s2289  TV Show                                      Friends
# 5138   s5138  TV Show                                 Red vs. Blue
#
#                               Director  \
# 5060  Lydia Dean Pilcher, Ginny Mohler
# 3062                       Rohena Gera
# 4710                   Mikael Håfström
# ...

# %%
#CATEGORY IS MOVIE AND TYPE IS DRAMA
data[(data['Category']=='Movie')&(data['Type']=='Dramas')]
# Out:
#      Show_Id Category                 Title                Director  \
# 4013   s4014    Movie       Meditation Park               Mina Shum
# 2367   s2368    Movie                Gemini          P.K. Baaburaaj
# 295     s296    Movie    Across Grace Alley           Ralph Macchio
# 1879   s1880    Movie       Driven to Dance                     NaN
# 5833   s5833    Movie        Strange Voices  Arthur Allan Seidelman
# ...      ...      ...                   ...                     ...
# 1273   s1274    Movie     Change in the Air           Dianne Dreyer
# 422     s423    Movie      All Together Now             Brett Haley
# 1909   s1910    Movie       East Side Sushi          Anthony Lucero
# 7414   s7413    Movie       Viceroy's House         Gurinder Chadha
# 4323   s4324    Movie  My Honor Was Loyalty         Alessandro Pepe
#
#                                                    Cast  \
# 4013  Cheng Pei-pei, Tzi Ma, Sandra Oh, Don McKellar...
# ...

# %%
#TOP YEARS
sns.countplot(x="Year",data=data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
#CATEGORY IS TV SHOW AND TYPE KIDS TV
data[(data['Category']=='TV Show')&(data['Type']=='kids tv')]# as their is no kids tv in tv show
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year, Time, Unit]
# Index: []

# %%
data[(data['Category']=='Movie')&(data['Type']=='Dramas')|(data['Category']=='TV Show')&(data['Type']=='kids tv')]
# Out:
#      Show_Id Category                 Title                Director  \
# 4013   s4014    Movie       Meditation Park               Mina Shum
# 2367   s2368    Movie                Gemini          P.K. Baaburaaj
# 295     s296    Movie    Across Grace Alley           Ralph Macchio
# 1879   s1880    Movie       Driven to Dance                     NaN
# 5833   s5833    Movie        Strange Voices  Arthur Allan Seidelman
# ...      ...      ...                   ...                     ...
# 1273   s1274    Movie     Change in the Air           Dianne Dreyer
# 422     s423    Movie      All Together Now             Brett Haley
# 1909   s1910    Movie       East Side Sushi          Anthony Lucero
# 7414   s7413    Movie       Viceroy's House         Gurinder Chadha
# 4323   s4324    Movie  My Honor Was Loyalty         Alessandro Pepe
#
#                                                    Cast  \
# 4013  Cheng Pei-pei, Tzi Ma, Sandra Oh, Don McKellar...
# ...

# %%
#DISTRIBUTION OF CONTENT RATING
rating=np.array(["R","TV-MA","PG-13","TV-14","TV-PG"])
distribution=np.array([665,2863,386,931,806])
f1={'family':'serif','color':'red','size':18}
f2={'family':'serif','color':'yellow','size':30}
plt.xlabel("RATING",fontdict=f1)
plt.ylabel("DISTRIBUTION",fontdict=f1)
plt.plot(rating,distribution)
plt.show()

# %%
data[(data['Category']=='Movie')]
# Out:
#      Show_Id Category                                              Title  \
# 7730   s7729    Movie                      You Don't Mess with the Zohan
# 5523   s5523    Movie                                           Sex Doll
# 5574   s5574    Movie                            Shootout at Lokhandwala
# 2953   s2954    Movie                                      Immoral Tales
# 2484   s2485    Movie                                    Good Luck Chuck
# ...      ...      ...                                                ...
# 3737   s3738    Movie                              Louis C.K.: Hilarious
# 3738   s3739    Movie               Louis C.K.: Live at the Comedy Store
# 3736   s3737    Movie                                    Louis C.K. 2017
# 4323   s4324    Movie                               My Honor Was Loyalty
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#                 Director                                               Cast  \
# ...

# %%
data[(data['Category']=='TV Show')]
# Out:
#      Show_Id Category                                  Title Director  \
# 4589   s4590  TV Show          Oh No! It's an Alien Invasion      NaN
# 1769   s1770  TV Show                          Dinosaur King      NaN
# 1856   s1857  TV Show              Dragons: Race to the Edge      NaN
# 5824   s5824  TV Show                              Stone Age      NaN
# 5845   s5845  TV Show  Stretch Armstrong & the Flex Fighters      NaN
# ...      ...      ...                                    ...      ...
# 6426   s6425  TV Show                The Great Train Robbery      NaN
# 1943   s1944  TV Show                               El Barco      NaN
# 5313   s5313  TV Show           Russell Peters vs. the World      NaN
# 2359   s2360  TV Show      Gargantia on the Verdurous Planet      NaN
# 3660   s3661  TV Show                           Little Lunch      NaN
#
#                                                    Cast         Country  \
# ...
